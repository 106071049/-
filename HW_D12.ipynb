# %%
pip install Pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install Numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd

# %%
#將資料夾中 boston.csv 讀進來，並用圖表分析欄位。
#畫出箱型圖，並判斷哪個欄位的中位數在 300~400 之間？  可看出 TAX跟B 的中位數在300~400間 可是 B的異常值太多了
data = pd.read_csv('boston.csv')
boxplot = data.boxplot(figsize=(10,8))
boxplot

# %%
#畫出散佈圖 x='NOX', y='DIS' ，並說明這兩欄位有什麼關係？  反比關係
data.plot.scatter(x='NOX', y='DIS')
